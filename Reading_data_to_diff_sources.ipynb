# %%
import pandas as pd

# %%
df = pd.read_csv('pandas_project/data/results.csv')
schema_df = pd.read_csv('pandas_project/data/schema.csv')

# %%
pd.set_option('display.max_columns',50)
pd.set_option('display.max_rows',50)

# %%
filt = (df['Country'] == 'India')
India_df = df.loc[filt]

# %%
India_df.head()
# Out:
#     ResponseId                                         MainBranch  \
# 17          18                     I am a developer by profession
# 58          59  I am not primarily a developer, but I write co...
# 75          76                              I am learning to code
# 89          90                              I am learning to code
# 96          97                     I am a developer by profession
#
#                 Age                                         Employment  \
# 17  18-24 years old  Independent contractor, freelancer, or self-em...
# 58  18-24 years old                                 Student, full-time
# 75  25-34 years old                 Not employed, but looking for work
# 89  25-34 years old                                Employed, full-time
# 96  25-34 years old                                Employed, full-time
#
#    RemoteWork   Check                                   CodingActivities  \
# ...

# %%
India_df.to_csv('modified.csv')
# Writing the filtered subset back to a new CSV file

# %%
India_df.to_csv('modified.tsv', sep='\t')
# Exporting data to a Tab-Separated Values (TSV) file using custom separator

# %%
tsv_df = pd.read_csv('modified.tsv',sep='\t')
