# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/amitkumar/Desktop/python-Git-learning-journey/pandas/data/results.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv('/Users/amitkumar/Desktop/python-Git-learning-journey/pandas/data/results.csv')
#
# AttributeError: module 'pandas' has no attribute 'read_csv'
